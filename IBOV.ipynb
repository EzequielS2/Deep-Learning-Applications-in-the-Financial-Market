# %% [markdown]
# # 1) Bibliotecas

# %%
# !pip install yfinance --upgrade --no-cache-dir
import yfinance as yf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 6.5 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2) Extração e tratamento dos dados.

# %%
tickers = "^BVSP"
carteira = yf.download(tickers, start="2018-01-01")["Close"]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
carteira
# Out:
# Date
# 2018-01-02     77891.00000
# 2018-01-03     77995.00000
# 2018-01-04     78647.00000
# 2018-01-05     79071.00000
# 2018-01-08     79379.00000
#                   ...
# 2022-11-07    115342.00000
# 2022-11-08    116160.00000
# 2022-11-09    113580.00000
# 2022-11-10    109775.00000
# 2022-11-11    112733.34375
# Name: Close, Length: 1205, dtype: float64

# %%
carteira = carteira.dropna()
carteira
# Out:
# Date
# 2018-01-02     77891.00000
# 2018-01-03     77995.00000
# 2018-01-04     78647.00000
# 2018-01-05     79071.00000
# 2018-01-08     79379.00000
#                   ...
# 2022-11-07    115342.00000
# 2022-11-08    116160.00000
# 2022-11-09    113580.00000
# 2022-11-10    109775.00000
# 2022-11-11    112733.34375
# Name: Close, Length: 1205, dtype: float64

# %%
carteira.columns = ["IBOV"]
carteira
# Out:
# Date
# 2018-01-02     77891.00000
# 2018-01-03     77995.00000
# 2018-01-04     78647.00000
# 2018-01-05     79071.00000
# 2018-01-08     79379.00000
#                   ...
# 2022-11-07    115342.00000
# 2022-11-08    116160.00000
# 2022-11-09    113580.00000
# 2022-11-10    109775.00000
# 2022-11-11    112733.34375
# Name: Close, Length: 1205, dtype: float64

# %% [markdown]
# # 3) Grafico índice Ibovespa.

# %%
sns.set()
carteira.plot(subplots=True, figsize=(22,8));
